# %% [markdown]
# #### quiz2 복습
# ___
# #### text 파일을 열어서 어떤 문자가 몇 번 등장했는지를 출력
# #### 등장 빈도순으로 출력 '가'-> 256회 '나'-> 230회 '1'-> 150회

# %%
f = open("test1_0112.txt" ,'r', encoding="UTF-8")   # 다른 폴더에 있는 텍스트 파일 열고 싶은데 잘 안됨
line = f.read()
# print(line)
f.close()
char= {}

for c in line:
    if c not in char:
        char[c]=1
    else:
        char[c]+=1
        
char1 = dict(sorted(char.items()))    # 딕셔너리key를 오름차순으로 정리하고 싶음
char1


for i,j in char1.items():
    print("''{}'' 의 등장횟수: {}".format(i,j))
# Out:
# ''
# '' 의 등장횟수: 101
# '' '' 의 등장횟수: 333
# ''#'' 의 등장횟수: 77
# ''''' 의 등장횟수: 110
# ''('' 의 등장횟수: 5
# '')'' 의 등장횟수: 5
# '','' 의 등장횟수: 40
# ''.'' 의 등장횟수: 42
# ''0'' 의 등장횟수: 7
# ''1'' 의 등장횟수: 27
# ''2'' 의 등장횟수: 16
# ''3'' 의 등장횟수: 11
# ''4'' 의 등장횟수: 7
# ''5'' 의 등장횟수: 8
# ''6'' 의 등장횟수: 5
# ''7'' 의 등장횟수: 9
# ''8'' 의 등장횟수: 5
# ''9'' 의 등장횟수: 3
# '':'' 의 등장횟수: 5
# ''='' 의 등장횟수: 9
# ''?'' 의 등장횟수: 3
# ''A'' 의 등장횟수: 6
# ''B'' 의 등장횟수: 9
# ''C'' 의 등장횟수: 3
# ''D'' 의 등장횟수: 1
# ''L'' 의 등장횟수: 2
# ''S'' 의 등장횟수: 2
# ''T'' 의 등장횟수: 2
# ''['' 의 등장횟수: 5
# '']'' 의 등장횟수: 5
# ''a'' 의 등장횟수: 16
# ''b'' 의 등장횟수: 3
# ''c'' 의 등장횟수: 5
# ''d'' 의 등장횟수: 6
# ''e'' 의 등장횟수: 37
# ''g'' 의 등장횟수: 4
# ''h'' 의 등장횟수: 4
# ''i'' 의 등장횟수: 12
# ''k'' 의 등장횟수: 12
# ''l'' 의 등장횟수: 29
# ''m'' 의 등장횟수: 3
# ''n'' 의 등장횟수: 8
# ''o'' 의 등장횟수: 17
# ''p'' 의 등장횟수: 9
# ''r'' 의 등장횟수: 11
# ''s'' 의 등장횟수: 21
# ''t'' 의 등장횟수: 34
# ''u'' 의 등장횟수: 15
# ''v'' 의 등장횟수: 6
# ''w'' 의 등장횟수: 2
# ''x'' 의 등장횟수: 5
# ''y'' 의 등장횟수: 17
# ''{'' 의 등장횟수: 4
# ''}'' 의 등장횟수: 4
# ''가'' 의 등장횟수: 19
# ''값'' 의 등장횟수: 10
# ''강'' 의 등장횟수: 1
# ''개'' 의 등장횟수: 4
# ''갯'' 의 등장횟수: 1
# ''거'' 의 등장횟수: 1
# ''게'' 의 등장횟수: 1
# ''고'' 의 등장횟수: 1
# ''과'' 의 등장횟수: 1
# ''교'' 의 등장횟수: 1
# ''구'' 의 등장횟수: 5
# ''균'' 의 등장횟수: 2
# ''금'' 의 등장횟수: 3
# ''기'' 의 등장횟수: 3
# ''길'' 의 등장횟수: 5
# ''까'' 의 등장횟수: 1
# ''꾸'' 의 등장횟수: 1
# ''끝'' 의 등장횟수: 2
# ''나'' 의 등장횟수: 1
# ''내'' 의 등장횟수: 3
# ''너'' 의 등장횟수: 1
# ''누'' 의 등장횟수: 1
# ''는'' 의 등장횟수: 17
# ''담'' 의 등장횟수: 1
# ''대'' 의 등장횟수: 5
# ''데'' 의 등장횟수: 6
# ''덱'' 의 등장횟수: 6
# ''도'' 의 등장횟수: 1
# ''되'' 의 등장횟수: 5
# ''두'' 의 등장횟수: 3
# ''드'' 의 등장횟수: 2
# ''든'' 의 등장횟수: 1
# ''딕'' 의 등장횟수: 1
# ''떻'' 의 등장횟수: 1
# ''라'' 의 등장횟수: 1
# ''랑'' 의 등장횟수: 1
# ''력'' 의 등장횟수: 32
# ''렬'' 의 등장횟수: 5
# ''로'' 의 등장횟수: 9
# ''록'' 의 등장횟수: 1
# ''류'' 의 등장횟수: 1
# ''를'' 의 등장횟수: 21
# ''름'' 의 등장횟수: 1
# ''리'' 의 등장횟수: 6
# ''림'' 의 등장횟수: 3
# ''만'' 의 등장횟수: 5
# ''맨'' 의 등장횟수: 2
# ''면'' 의 등장횟수: 1
# ''명'' 의 등장횟수: 1
# ''몇'' 의 등장횟수: 5
# ''모'' 의 등장횟수: 1
# ''목'' 의 등장횟수: 1
# ''문'' 의 등장횟수: 2
# ''바'' 의 등장횟수: 1
# ''반'' 의 등장횟수: 1
# ''번'' 의 등장횟수: 11
# ''복'' 의 등장횟수: 1
# ''부'' 의 등장횟수: 1
# ''분'' 의 등장횟수: 1
# ''빨'' 의 등장횟수: 1
# ''삭'' 의 등장횟수: 6
# ''삽'' 의 등장횟수: 2
# ''새'' 의 등장횟수: 1
# ''서'' 의 등장횟수: 11
# ''성'' 의 등장횟수: 16
# ''세'' 의 등장횟수: 43
# ''셔'' 의 등장횟수: 1
# ''소'' 의 등장횟수: 13
# ''수'' 의 등장횟수: 6
# ''순'' 의 등장횟수: 4
# ''스'' 의 등장횟수: 13
# ''안'' 의 등장횟수: 1
# ''양'' 의 등장횟수: 1
# ''어'' 의 등장횟수: 4
# ''없'' 의 등장횟수: 3
# ''에'' 의 등장횟수: 21
# ''오'' 의 등장횟수: 2
# ''와'' 의 등장횟수: 2
# ''왕'' 의 등장횟수: 3
# ''요'' 의 등장횟수: 48
# ''우'' 의 등장횟수: 1
# ''원'' 의 등장횟수: 4
# ''위'' 의 등장횟수: 1
# ''으'' 의 등장횟수: 8
# ''을'' 의 등장횟수: 25
# ''의'' 의 등장횟수: 17
# ''이'' 의 등장횟수: 11
# ''인'' 의 등장횟수: 25
# ''입'' 의 등장횟수: 2
# ''있'' 의 등장횟수: 7
# ''자'' 의 등장횟수: 3
# ''장'' 의 등장횟수: 1
# ''재'' 의 등장횟수: 3
# ''전'' 의 등장횟수: 2
# ''정'' 의 등장횟수: 7
# ''제'' 의 등장횟수: 7
# ''존'' 의 등장횟수: 3
# ''준'' 의 등장횟수: 3
# ''지'' 의 등장횟수: 18
# ''집'' 의 등장횟수: 14
# ''차'' 의 등장횟수: 6
# ''천'' 의 등장횟수: 1
# ''총'' 의 등장횟수: 1
# ''최'' 의 등장횟수: 4
# ''추'' 의 등장횟수: 5
# ''출'' 의 등장횟수: 32
# ''치'' 의 등장횟수: 2
# ''칭'' 의 등장횟수: 1
# ''태'' 의 등장횟수: 1
# ''턴'' 의 등장횟수: 2
# ''토'' 의 등장횟수: 2
# ''튜'' 의 등장횟수: 1
# ''트'' 의 등장횟수: 1
# ''파'' 의 등장횟수: 1
# ''평'' 의 등장횟수: 2
# ''포'' 의 등장횟수: 3
# ''플'' 의 등장횟수: 1
# ''하'' 의 등장횟수: 43
# ''한'' 의 등장횟수: 1
# ''함'' 의 등장횟수: 3
# ''합'' 의 등장횟수: 19
# ''해'' 의 등장횟수: 3
# ''화'' 의 등장횟수: 2
# ''확'' 의 등장횟수: 10
# ''환'' 의 등장횟수: 2
# ''황'' 의 등장횟수: 1

# %%
print(type(line))
# Out:
# <class 'str'>

# %% [markdown]
# ### 특수문자, 공백 빼기
# #### 1. 처음부터 전처리 후 세기
# #### 2. 카운트 끝나고 마지막에 제거하기

# %%
# 1
import string
f = open("test1_0112.txt" ,'r', encoding="UTF-8")   
line = f.read()

lst=[]
# 비어있는 리스트에 특수문자 아닌 것을 모으자
for c in line:
    if c not in string.punctuation:
        lst.append(c)
# print(lst,end='')       
# '\n' 지우기 (특수문자에 포함 안된 기호)  리스트의 특정값 모두 지우는 다른 방법은 없을까?
for c in line:
    if c in '\n':
        lst.remove(c)
# print(lst,end='')

char = {}

for c in lst:
    if c not in char:
        char[c]=1
    else:
        char[c]+=1
        
for k,v in char.items():
    print("{} 의 등장횟수 = {}".format(k,v))
# Out:
# ['S', 't', 'r', 'i', 'n', 'g', 't', 'x', 't', '1', ' ', ' ', 'A', ' ', 't', 'a', 'l', 'e', ' ', 't', 'h', 'a', 't', ' ', 'w', 'a', 's', ' ', 'n', 'o', 't', ' ', 'r', 'i', 'g', 'h', 't', ' ', 'a', 'l', 'e', ' ', '이', ' ', '출', '력', ' ', 'A', ' ', 't', 'a', 'l', 'e', ' ', '출', '력', ' ', 'n', 'o', 't', ' ', '출', '력', ' ', 't', 'x', 't', '1', '을', ' ', '소', '문', '자', ' ', '전', '환', ' ', 't', 'x', 't', '1', '을', ' ', '대', '문', '자', ' ', '전', '환', ' ', 'o', '가', ' ', '몇', ' ', '개', ' ', '존', '재', '하', '는', '가', ' ', 'o', '가', ' ', '몇', ' ', '번', ' ', '인', '덱', '스', '에', ' ', '존', '재', '하', '는', '가', ' ', 't', 'x', 't', '1', '의', ' ', '길', '이', '는', ' ', '어', '떻', '게', ' ', '되', '는', '가', ' ', 's', 'p', 'a', 'c', 'e', '를', ' ', '기', '준', '으', '로', ' ', '나', '누', '어', '서', ' ', 'L', 'i', 's', 't', '에', ' ', '담', '으', '세', '요', ' ', 't', 'a', 'l', 'e', '을', ' ', 's', 't', 'o', 'r', 'y', '로', ' ', '바', '꾸', '세', '요', ' ', 't', 'x', 't', '1', ' ', '안', '에', ' ', 'r', 'i', 'g', 'h', 't', '가', ' ', '존', '재', '하', '는', '지', ' ', '확', '인', 'L', 'i', 's', 't', 's', 'o', 'l', ' ', ' ', '태', '양', '수', '성', '금', '성', '지', '구', '화', '성', '목', '성', '지', '구', 's', 'o', 'l', '1', ' ', ' ', '토', '성', '천', '황', '성', '해', '왕', '성', 'p', 'l', 'a', 'n', 'e', 't', ' ', ' ', '지', '구', ' ', '1', ' ', 's', 'o', 'l', '에', '서', ' ', '수', '성', '금', '성', '을', ' ', '출', '력', ' ', '2', ' ', 's', 'o', 'l', '에', '서', ' ', '지', '구', ' ', '위', '치', ' ', '인', '덱', '스', ' ', '출', '력', ' ', '3', ' ', 's', 'o', 'l', '에', '서', ' ', '화', '성', '을', ' ', '해', '왕', '성', '으', '로', ' ', '수', '정', ' ', '4', ' ', '수', '성', '자', '리', '에', ' ', '명', '왕', '성', ' ', '삽', '입', ' ', '5', ' ', '토', '성', '을', ' ', '맨', ' ', '끝', '에', ' ', '삽', '입', ' ', '6', ' ', '맨', ' ', '끝', ' ', '요', '소', '를', ' ', '삭', '제', '하', '고', ' ', '리', '턴', ' ', '7', ' ', '금', '성', '을', ' ', '제', '거', ' ', '8', ' ', '1', '번', ' ', '인', '덱', '스', '에', '서', ' ', '3', '번', ' ', '인', '덱', '스', '까', '지', ' ', '삭', '제', ' ', '9', ' ', '인', '덱', '스', ' ', '2', '번', ' ', '요', '소', ' ', '삭', '제', ' ', '1', '0', ' ', 's', 'o', 'l', '과', ' ', 's', 'o', 'l', '1', '을', ' ', '합', '치', '세', '요', ' ', '1', '1', ' ', '내', '림', '차', '순', ' ', '정', '렬', ' ', '1', '2', ' ', '오', '름', '차', '순', ' ', '정', '렬', ' ', '1', '3', ' ', '만', '리', '장', '성', '이', ' ', '있', '는', '지', ' ', '확', '인', ' ', '1', '4', ' ', 's', 'o', '1', '을', ' ', '3', '번', ' ', '반', '복', '하', '세', '요', ' ', '1', '5', ' ', '길', '이', '를', ' ', '출', '력', '하', '세', '요', ' ', '1', '6', ' ', '지', '구', '가', ' ', '몇', ' ', '개', ' ', '포', '함', '되', '어', '있', '는', '지', ' ', '확', '인', ' ', '1', '7', ' ', '모', '든', ' ', '원', '소', '를', ' ', '지', '우', '세', '요', ' ', '1', '8', ' ', 's', 'o', 'l', '리', '스', '트', '를', ' ', '삭', '제', '하', '세', '요', 'T', 'u', 'p', 'l', 'e', 'm', 'y', 'T', 'u', 'p', 'l', 'e', ' ', ' ', 't', 'u', 'p', 'l', 'e', ' ', '1', '2', '3', ' ', ' ', '4', '5', '6', '7', '8', ' ', '7', ' ', '8', ' ', '9', ' ', 't', 'u', 'p', 'l', 'e', '을', ' ', '출', '력', '하', '세', '요', ' ', '3', '을', ' ', '출', '력', '하', '세', '요', ' ', '4', '5', '를', ' ', '출', '력', '하', '세', '요', ' ', '4', '5', '6', '을', ' ', '출', '력', '하', '세', '요', ' ', 't', 'u', 'p', 'l', 'e', '의', ' ', '길', '이', '를', ' ', '리', '턴', '하', '세', '요', ' ', ' ', '요', '소', '의', ' ', '갯', '수', '가', ' ', '몇', ' ', '개', '인', '지', ' ', ' ', '7', '이', ' ', '있', '는', '지', ' ', '확', '인', '하', '세', '요', ' ', '7', '의', ' ', '인', '덱', '스', '를', ' ', '출', '력', '하', '세', '요', ' ', '7', '이', ' ', '몇', ' ', '개', ' ', '있', '는', '지', ' ', '확', '인', '하', '세', '요', ' ', '인', '데', '스', ' ', '2', '번', '를', ' ', '출', '력', '하', '세', '요', ' ', '인', '데', '스', ' ', '2', '번', '에', '서', ' ', '최', '대', '값', '을', ' ', '출', '력', '하', '세', '요', ' ', '인', '데', '스', ' ', '2', '번', '에', '서', ' ', '최', '소', '값', '을', ' ', '출', '력', '하', '세', '요', ' ', '인', '데', '스', ' ', '2', '번', '에', '서', ' ', '총', '합', '을', ' ', '출', '력', '하', '세', '요', ' ', '인', '데', '스', ' ', '2', '번', '에', '서', ' ', '평', '균', '을', ' ', '출', '력', '하', '세', '요', ' ', '인', '데', ...
# t 의 등장횟수 = 34
# r 의 등장횟수 = 11
# i 의 등장횟수 = 12
# n 의 등장횟수 = 8
# g 의 등장횟수 = 4
# x 의 등장횟수 = 5
# 1 의 등장횟수 = 27
#   의 등장횟수 = 333
# A 의 등장횟수 = 6
# a 의 등장횟수 = 16
# l 의 등장횟수 = 29
# e 의 등장횟수 = 37
# h 의 등장횟수 = 4
# w 의 등장횟수 = 2
# s 의 등장횟수 = 21
# o 의 등장횟수 = 17
# 이 의 등장횟수 = 11
# 출 의 등장횟수 = 32
# 력 의 등장횟수 = 32
# 을 의 등장횟수 = 25
# 소 의 등장횟수 = 13
# 문 의 등장횟수 = 2
# 자 의 등장횟수 = 3
# 전 의 등장횟수 = 2
# 환 의 등장횟수 = 2
# 대 의 등장횟수 = 5
# 가 의 등장횟수 = 19
# 몇 의 등장횟수 = 5
# 개 의 등장횟수 = 4
# 존 의 등장횟수 = 3
# 재 의 등장횟수 = 3
# 하 의 등장횟수 = 43
# 는 의 등장횟수 = 17
# 번 의 등장횟수 = 11
# 인 의 등장횟수 = 25
# 덱 의 등장횟수 = 6
# 스 의 등장횟수 = 13
# 에 의 등장횟수 = 21
# 의 의 등장횟수 = 17
# 길 의 등장횟수 = 5
# 어 의 등장횟수 = 4
# 떻 의 등장횟수 = 1
# 게 의 등장횟수 = 1
# 되 의 등장횟수 = 5
# p 의 등장횟수 = 9
# c 의 등장횟수 = 5
# 를 의 등장횟수 = 21
# 기 의 등장횟수 = 3
# 준 의 등장횟수 = 3
# 으 의 등장횟수 = 8
# 로 의 등장횟수 = 9
# 나 의 등장횟수 = 1
# 누 의 등장횟수 = 1
# 서 의 등장횟수 = 11
# L 의 등장횟수 = 2
# 담 의 등장횟수 = 1
# 세 의 등장횟수 = 43
# 요 의 등장횟수 = 48
# y 의 등장횟수 = 17
# 바 의 등장횟수 = 1
# 꾸 의 등장횟수 = 1
# 안 의 등장횟수 = 1
# 지 의 등장횟수 = 18
# 확 의 등장횟수 = 10
# 태 의 등장횟수 = 1
# 양 의 등장횟수 = 1
# 수 의 등장횟수 = 6
# 성 의 등장횟수 = 16
# 금 의 등장횟수 = 3
# 구 의 등장횟수 = 5
# 화 의 등장횟수 = 2
# 목 의 등장횟수 = 1
# 토 의 등장횟수 = 2
# 천 의 등장횟수 = 1
# 황 의 등장횟수 = 1
# 해 의 등장횟수 = 3
# 왕 의 등장횟수 = 3
# 2 의 등장횟수 = 16
# 위 의 등장횟수 = 1
# 치 의 등장횟수 = 2
# 3 의 등장횟수 = 11
# 정 의 등장횟수 = 7
# 4 의 등장횟수 = 7
# 리 의 등장횟수 = 6
# 명 의 등장횟수 = 1
# 삽 의 등장횟수 = 2
# 입 의 등장횟수 = 2
# 5 의 등장횟수 = 8
# 맨 의 등장횟수 = 2
# 끝 의 등장횟수 = 2
# 6 의 등장횟수 = 5
# 삭 의 등장횟수 = 6
# 제 의 등장횟수 = 7
# 고 의 등장횟수 = 1
# 턴 의 등장횟수 = 2
# 7 의 등장횟수 = 9
# 거 의 등장횟수 = 1
# 8 의 등장횟수 = 5
# 까 의 등장횟수 = 1
# 9 의 등장횟수 = 3
# 0 의 등장횟수 = 7
# 과 의 등장횟수 = 1
# 합 의 등장횟수 = 19
# 내 의 등장횟수 = 3
# 림 의 등장횟수 = 3
# 차 의 등장횟수 = 6
# 순 의 등장횟수 = 4
# 렬 의 등장횟수 = 5
# 오 의 등장횟수 = 2
# 름 의 등장횟수 = 1
# 만 의 등장횟수 = 5
# 장 의 등장횟수 = 1
# 있 의 등장횟수 = 7
# 반 의 등장횟수 = 1
# 복 의 등장횟수 = 1
# 포 의 등장횟수 = 3
# 함 의 등장횟수 = 3
# 모 의 등장횟수 = 1
# 든 의 등장횟수 = 1
# 원 의 등장횟수 = 4
# 우 의 등장횟수 = 1
# 트 의 등장횟수 = 1
# T 의 등장횟수 = 2
# u 의 등장횟수 = 15
# m 의 등장횟수 = 3
# 갯 의 등장횟수 = 1
# 데 의 등장횟수 = 6
# 최 의 등장횟수 = 4
# 값 의 등장횟수 = 10
# 총 의 등장횟수 = 1
# 평 의 등장횟수 = 2
# 균 의 등장횟수 = 2
# 없 의 등장횟수 = 3
# 드 의 등장횟수 = 2
# k 의 등장횟수 = 12
# 와 의 등장횟수 = 2
# 추 의 등장횟수 = 5
# 두 의 등장횟수 = 3
# B 의 등장횟수 = 9
# C 의 등장횟수 = 3
# 집 의 등장횟수 = 14
# 교 의 등장횟수 = 1
# 한 의 등장횟수 = 1
# 칭 의 등장횟수 = 1
# 부 의 등장횟수 = 1
# 분 의 등장횟수 = 1
# D 의 등장횟수 = 1
# d 의 등장횟수 = 6
# 라 의 등장횟수 = 1
# 딕 의 등장횟수 = 1
# 셔 의 등장횟수 = 1
# 너 의 등장횟수 = 1
# b 의 등장횟수 = 3
# v 의 등장횟수 = 6
# 튜 의 등장횟수 = 1
# 플 의 등장횟수 = 1
# 류 의 등장횟수 = 1
# 도 의 등장횟수 = 1
# 록 의 등장횟수 = 1
# 면 의 등장횟수 = 1
# 새 의 등장횟수 = 1
# 파 의 등장횟수 = 1
# 랑 의 등장횟수 = 1
# 빨 의 등장횟수 = 1
# 강 의 등장횟수 = 1
